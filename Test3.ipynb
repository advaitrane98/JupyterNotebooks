# %%
#page1

import pandas as pd
# data_df=  pd.read_csv(r'C:\Users\advai\Downloads\Data-30mins.csv')
data_df=  pd.read_csv(r'C:\Users\advai\Downloads\Data-1hr.csv')
# data_df=  pd.read_csv(r'C:\Users\advai\Downloads\raw_data_83_days.csv')
k= 200*(data_df.at[0,'BTC/USD']/data_df.at[0,'ADA/USD'])

def format_float(value):
    return f'{value:,.5f}'
pd.options.display.float_format = format_float

rows=data_df.shape[0]
a = []
for i in range (0,rows):
    b = []
#     print(i)
    for j in range(i,rows):
        if j==i:
            k=200*(data_df.at[i,'BTC/USD']/data_df.at[i,'ADA/USD'])
        
        
        else:
#               data_df.at[i,'constant']=data_df.at[0,'constant']*(data_df.at[i,'ADA/USD']/data_df.at[i,'BTC/USD'])
            z=k*(data_df.at[j,'ADA/USD']/data_df.at[j,'BTC/USD'])
            b.append(z)
    a.append(b)

# %%
#page2
MCR=120
x=[]
for m in range (0,len(a)):
    y=a[m]
    for n in range (0,len(y)):    
        f = 0 
        if y[n] < MCR:
            f = 1
#             print(n)
            x.append(n)
            break
    if f == 0:
        x.append(0)
#         print(n)

# %%
#page3
# a
x
# Out:
# [1325,
#  1322,
#  1315,
#  1279,
#  1269,
#  1312,
#  1317,
#  1318,
#  1317,
#  1316,
#  1315,
#  1314,
#  1311,
#  1310,
#  1309,
#  1310,
#  1309,
#  1306,
#  1307,
#  1335,
#  1345,
#  1346,
#  1346,
#  1341,
#  1315,
#  1300,
#  1297,
#  1315,
#  1297,
#  1313,
#  1299,
#  1310,
#  1293,
#  1321,
#  1323,
#  1294,
#  1306,
#  1305,
#  1330,
#  1328,
#  1326,
#  1324,
#  1312,
#  1324,
#  1319,
#  1312,
#  1316,
#  1315,
#  1316,
#  1316,
#  1316,
#  1317,
#  1315,
#  1313,
#  1310,
#  1311,
#  1312,
#  1311,
#  1310,
#  1308,
#  1308,
#  1307,
#  1306,
#  1305,
#  1304,
#  1303,
#  1302,
#  1301,
#  1300,
#  1299,
#  1535,
#  1534,
#  1536,
#  1554,
#  1531,
#  1294,
#  1292,
#  1528,
#  1526,
#  1289,
#  1288,
#  1524,
#  1523,
#  1486,
#  1284,
#  1283,
#  1282,
#  1281,
#  1279,
#  1252,
#  1235,
#  1234,
#  1190,
#  1223,
#  1223,
#  1221,
#  1221,
#  1219,
#  1225,
#  1218,
#  1223,
#  1169,
#  1221,
#  1220,
#  1221,
#  1220,
#  1217,
#  1218,
#  1217,
#  1216,
#  1215,
#  1214,
#  1213,
#  1212,
#  1211,
#  1208,
#  1209,
#  1208,
#  1207,
#  1206,
#  1205,
#  1204,
#  1203,
#  1200,
#  1201,
#  1200,
#  1199,
#  1198,
#  1197,
#  1225,
#  1199,
#  1198,
#  1193,
#  1192,
#  1191,
#  1188,
#  1137,
#  1136,
#  1132,
#  1134,
#  1183,
#  1175,
#  1175,
#  1180,
#  1172,
#  1170,
#  1170,
#  1176,
#  1175,
#  1174,
#  1167,
#  1165,
#  1171,
#  1170,
#  1169,
#  1162,
#  1167,
#  1159,
#  1159,
#  1164,
#  1163,
#  1162,
#  1161,
#  1162,
#  1159,
#  1158,
#  1157,
#  1158,
#  1161,
#  1156,
#  1155,
#  1154,
#  1151,
#  1152,
#  1151,
#  1148,
#  1097,
#  1138,
#  1137,
#  1144,
#  1143,
#  1136,
#  1135,
#  1133,
#  1133,
#  1097,
#  1137,
#  1136,
#  1135,
#  1134,
#  1133,
#  1132,
#  1125,
#  1130,
#  1129,
#  1128,
#  1127,
#  1126,
#  1125,
#  1124,
#  1117,
#  1122,
#  1121,
#  1120,
#  1119,
#  1112,
#  1117,
#  1066,
#  1107,
#  1107,
#  1105,
#  1071,
#  1061,
#  1060,
#  1102,
#  1102,
#  1107,
#  1100,
#  1105,
#  1098,
#  1103,
#  1102,
#  1101,
#  1047,
#  1038,
#  966,
#  961,
#  949,
#  959,
#  1033,
#  1036,
#  962,
#  959,
#  1029,
#  1028,
#  1027,
#  1046,
#  1079,
#  1035,
#  1027,
#  1030,
#  1025,
#  1028,
#  1019,
#  1026,
#  1025,
#  1024,
#  1023,
#  1025,
#  1021,
#  1020,
#  1022,
#  1030,
#  1017,
#  1016,
#  1018,
#  1017,
#  1025,
#  1065,
#  1064,
#  1063,
#  1021,
#  1053,
#  1052,
#  1052,
#  1050,
#  1050,
#  1050,
#  1049,
#  1013,
#  1047,
#  1046,
#  1051,
#  1044,
#  1051,
#  1048,
#  1047,
#  1046,
#  1045,
#  1046,
#  1043,
#  1042,
#  1041,
#  1042,
#  1041,
#  1040,
#  1056,
#  1054,
#  1051,
#  1065,
#  1052,
#  1063,
#  1062,
#  1064,
#  1060,
#  1059,
#  1029,
#  1031,
#  1027,
#  1030,
#  1041,
#  1024,
#  1023,
#  1039,
#  1037,
#  1037,
#  1034,
#  1035,
#  1034,
#  1045,
#  1032,
#  1031,
#  1017,
#  1012,
#  1028,
#  1039,
#  1049,
#  1048,
#  1047,
#  1047,
#  1046,
#  1045,
#  1043,
#  1043,
#  1041,
#  1040,
#  1039,
#  1038,
#  1037,
#  1039,
#  1038,
#  1037,
#  1036,
#  1035,
#  1034,
#  1033,
#  1032,
#  1031,
#  1030,
#  1029,
#  1265,
#  1265,
#  1266,
#  1284,
#  1261,
#  1263,
#  1262,
#  1261,
#  1489,
#  1360,
#  1487,
#  1863,
#  1343,
#  1347,
#  1355,
#  1481,
#  1870,
#  1337,
#  1269,
#  1853,
#  1477,
#  1851,
#  1475,
#  1474,
#  1271,
#  1240,
#  1242,
#  1260,
#  1238,
#  1266,
#  1265,
#  1264,
#  1465,
#  1842,
#  1838,
#  1462,
#  1836,
#  1460,
#  1322,
#  1321,
#  1457,
#  1257,
#  1312,
#  1254,
#  1251,
#  1309,
#  1309,
#  1322,
#  1220,
#  1219,
#  1237,
#  1244,
#  1245,
#  1242,
#  1241,
#  1210,
#  972,
#  971,
#  966,
#  967,
#  966,
#  965,
#  966,
#  965,
#  964,
#  963,
#  962,
#  962,
#  1197,
#  1196,
#  1195,
#  1158,
#  1192,
#  1191,
#  1155,
#  953,
#  953,
#  951,
#  950,
#  949,
#  1185,
#  1206,
#  1205,
#  1204,
#  1181,
#  1183,
#  1201,
#  1208,
#  1408,
#  1206,
#  1208,
#  1204,
#  1203,
#  1204,
#  1204,
#  1200,
#  1199,
#  1197,
#  1189,
#  1188,
#  1187,
#  1194,
#  1166,
#  1165,
#  1183,
#  1163,
#  1162,
#  1158,
#  880,
#  833,
#  823,
#  866,
#  871,
#  820,
#  828,
#  827,
#  810,
#  816,
#  812,
#  814,
#  879,
#  862,
#  900,
#  878,
#  890,
#  877,
#  899,
#  898,
#  896,
#  873,
#  884,
#  891,
#  891,
#  890,
#  851,
#  850,
#  849,
#  848,
#  847,
#  803,
#  835,
#  835,
#  872,
#  871,
#  878,
#  880,
#  882,
#  882,
#  1116,
#  1116,
#  1079,
#  877,
#  1112,
#  1142,
#  1133,
#  1113,
#  1112,
#  1107,
#  1107,
#  1128,
#  1105,
#  1103,
#  1102,
#  865,
#  1101,
#  863,
#  1099,
#  1120,
#  1100,
#  1118,
#  1117,
#  1116,
#  1123,
#  1122,
#  1121,
#  1120,
#  1119,
#  1118,
#  1117,
#  1175,
#  1174,
#  1188,
#  1315,
#  1691,
#  1313,
#  1312,
#  1310,
#  1310,
#  1682,
#  1683,
#  1555,
#  1683,
#  1682,
#  1678,
#  1680,
#  1678,
#  1676,
#  1677,
#  1676,
#  1673,
#  1674,
#  1671,
#  1672,
#  1671,
#  1670,
#  1669,
#  1163,
#  1090,
#  1087,
#  1086,
#  1085,
#  1084,
#  1083,
#  1084,
#  1155,
#  1145,
#  1153,
#  1138,
#  1279,
#  1278,
#  1277,
#  1276,
#  1147,
#  1274,
#  1273,
#  1272,
#  1271,
#  1142,
#  1268,
#  1268,
#  1267,
#  1266,
#  1638,
#  1639,
#  1637,
#  1634,
#  1636,
#  1633,
#  1635,
#  1633,
#  1634,
#  1633,
#  1630,
#  1631,
#  1630,
#  1629,
#  1628,
#  1627,
#  1626,
#  1625,
#  1624,
#  1624,
#  1624,
#  1623,
#  1620,
#  1621,
#  1619,
#  1619,
#  1617,
#  1617,
#  1616,
#  1615,
#  1614,
#  1613,
#  1612,
#  1611,
#  1613,
#  1609,
#  1611,
#  1607,
#  1606,
#  1608,
#  1613,
#  1612,
#  1611,
#  1610,
#  1600,
#  1599,
#  1601,
#  1597,
#  1599,
#  1604,
#  1603,
#  1602,
#  1601,
#  1594,
#  1599,
#  1598,
#  1597,
#  1597,
#  1596,
#  1594,
#  1593,
#  1593,
#  1591,
#  1590,
#  1580,
#  1588,
#  1581,
#  1580,
#  1585,
#  1584,
#  1583,
#  1573,
#  1572,
#  1574,
#  1579,
#  1572,
#  1577,
#  1577,
#  1576,
#  1575,
#  1574,
#  1573,
#  1577,
#  1575,
#  1589,
#  1574,
#  1573,
#  1571,
#  1571,
#  1584,
#  1569,
#  1568,
#  1567,
#  1580,
#  1563,
#  1552,
#  1557,
#  1557,
#  1556,
#  1555,
#  1558,
#  1553,
#  1556,
#  1554,
#  1550,
#  1549,
#  1548,
#  1537,
#  1536,
#  1545,
#  1544,
#  1543,
#  1541,
#  1534,
#  1533,
#  1538,
#  1528,
#  1525,
#  1524,
#  1524,
#  1524,
#  1523,
#  1532,
#  1530,
#  1530,
#  1529,
#  1528,
#  1527,
#  1526,
#  1525,
#  1524,
#  1523,
#  1522,
#  1521,
#  1520,
#  1519,
#  1508,
#  1505,
#  1505,
#  1503,
#  1503,
#  1503,
#  1501,
#  1500,
#  1498,
#  1497,
#  1492,
#  1495,
#  1491,
#  1488,
#  987,
#  1114,
#  1113,
#  984,
#  1111,
#  1110,
#  1109,
#  966,
#  1107,
#  1106,
#  1105,
#  1104,
#  1478,
#  1477,
#  1478,
#  1477,
#  1474,
#  1473,
#  1471,
#  1473,
#  1472,
#  1471,
#  1469,
#  1469,
#  1468,
#  1467,
#  1466,
#  951,
#  1087,
#  944,
#  1084,
#  1084,
#  1083,
#  1082,
#  1454,
#  1080,
#  1079,
#  1455,
#  1454,
#  607,
#  876,
#  872,
#  871,
#  872,
#  861,
#  868,
#  867,
#  858,
#  857,
#  856,
#  855,
#  854,
#  834,
#  830,
#  830,
#  591,
#  590,
#  589,
#  587,
#  587,
#  787,
#  585,
#  584,
#  583,
#  581,
#  578,
#  578,
#  568,
#  572,
#  574,
#  573,
#  574,
#  574,
#  774,
#  808,
#  808,
#  829,
#  836,
#  827,
#  826,
#  825,
#  832,
#  831,
#  830,
#  829,
#  830,
#  830,
#  826,
#  827,
#  827,
#  823,
#  822,
#  823,
#  879,
#  822,
#  878,
#  877,
#  890,
#  1017,
#  1016,
#  1015,
#  1014,
#  1013,
#  1387,
#  1385,
#  1384,
#  1257,
#  1381,
#  1381,
#  1379,
#  1380,
#  1379,
#  1378,
#  1379,
#  1376,
#  1375,
#  1376,
#  1375,
#  1374,
#  1371,
#  1371,
#  1368,
#  1370,
#  1369,
#  1367,
#  1365,
#  1364,
#  1365,
#  1362,
#  1361,
#  1362,
#  1359,
#  1358,
#  1357,
#  1356,
#  1356,
#  1356,
#  1355,
#  1354,
#  1354,
#  1354,
#  1362,
#  1352,
#  1351,
#  1350,
#  1349,
#  1357,
#  1347,
#  1355,
#  1348,
#  1353,
#  1352,
#  1345,
#  1348,
#  1339,
#  1338,
#  1337,
#  1337,
#  1334,
#  1333,
#  1333,
#  1333,
#  1332,
#  1340,
#  1330,
#  1338,
#  1331,
#  1330,
#  1326,
#  1325,
#  1324,
#  1323,
#  1325,
#  1330,
#  1330,
#  1329,
#  1328,
#  1327,
#  1326,
#  1328,
#  1327,
#  1326,
#  1322,
#  1321,
#  1320,
#  1319,
#  1318,
#  1317,
#  1316,
#  1315,
#  1314,
#  1313,
#  1312,
#  1311,
#  1310,
#  1309,
#  1308,
#  1307,
#  1306,
#  1308,
#  1304,
#  1304,
#  1305,
#  1305,
#  1303,
#  1303,
#  1303,
#  1316,
#  1339,
#  1338,
#  1378,
#  1336,
#  1335,
#  1310,
#  1333,
#  1308,
#  1372,
#  1330,
#  1370,
#  1328,
#  1368,
#  1367,
#  1366,
#  1366,
#  1365,
#  1364,
#  1363,
#  1362,
#  1361,
#  1359,
#  1358,
#  1357,
#  1315,
#  1290,
#  1289,
#  1273,
#  1268,
#  1270,
#  1269,
#  1269,
#  1268,
#  1267,
#  1266,
#  1280,
#  1279,
#  1278,
#  1277,
#  1276,
#  1275,
#  1260,
#  1259,
#  1258,
#  1257,
#  1270,
#  1269,
#  1254,
#  1253,
#  1252,
#  1251,
#  1250,
#  1263,
#  1262,
#  1261,
#  1284,
#  1324,
#  1258,
#  1257,
#  1280,
#  1320,
#  1319,
#  1319,
#  1320,
#  1319,
#  1318,
#  1331,
#  1316,
#  1315,
#  1314,
#  ...]

# %%
#page4

#mean

def get_mean(ls):
    v=[]
    for r in ls:
        if r==0:
            continue
        else:
            v.append(r)
    return sum(v)/len(v)


#median with unique entries


def get_median(ls):
    q=[]
    for r in ls:
        if r not in q:
            q.append(r)
    # sort the list
            q.sort()
#     print(q)
        
    # find the median
    if len(q) % 2 != 0:
        m = int((len(q)+1)/2 - 1)
        return q[m]
    else:
        m1 = int(len(q)/2 - 1)
        m2 = int(len(q)/2)
        return (q[m1]+q[m2])/2

#probability of liquidation/no of cases where liquidation occurs
def get_prob(ls):
    u=[]
    w=len(ls)
    for r in ls:
        if r!=0:
            u.append(r)
    return (len(u)/len(ls))*100

    
print("mean:"+str(get_mean(x)))
print("median:"+str(get_median(x)))
print("probability of liquidation:"+str(get_prob(x)))
# Out:
# mean:2374.4588878760255
# median:2392.5
# probability of liquidation:63.30063473744951

# %%
#page1 ETH

import pandas as pd
# data_df=  pd.read_csv(r'C:\Users\advai\Downloads\Data-30mins.csv')
data_df=  pd.read_csv(r'C:\Users\advai\Downloads\Data-1hr.csv')
# data_df=  pd.read_csv(r'C:\Users\advai\Downloads\raw_data_83_days.csv')
# k= 200*(data_df.at[0,'BTC/USD']/data_df.at[0,'ADA/USD'])

def format_float(value):
    return f'{value:,.5f}'
pd.options.display.float_format = format_float

rows=data_df.shape[0]
a = []
for i in range (0,rows):
    b = []
#     print(i)
    for j in range(i,rows):
        if j==i:
            k=200*(data_df.at[i,'ETH/USD']/data_df.at[i,'ADA/USD'])
        
        
        else:
#               data_df.at[i,'constant']=data_df.at[0,'constant']*(data_df.at[i,'ADA/USD']/data_df.at[i,'BTC/USD'])
            z=k*(data_df.at[j,'ADA/USD']/data_df.at[j,'ETH/USD'])
            b.append(z)
    a.append(b)

# %%
#page2
MCR=120
x=[]
for m in range (0,len(a)):
    y=a[m]
    for n in range (0,len(y)):    
        f = 0 
        if y[n] < MCR:
            f = 1
#             print(n)
            x.append(n)
            break
    if f == 0:
        x.append(0)
#         print(n)

# %%
#page3
# a
x
# Out:
# [1468,
#  1467,
#  1460,
#  1392,
#  1387,
#  1391,
#  1462,
#  1461,
#  1484,
#  1500,
#  1483,
#  1498,
#  1456,
#  1455,
#  1454,
#  1453,
#  1477,
#  1451,
#  1475,
#  1496,
#  1525,
#  1525,
#  1527,
#  1492,
#  1444,
#  1443,
#  1370,
#  1466,
#  1440,
#  1480,
#  1463,
#  1464,
#  1436,
#  1476,
#  1475,
#  1433,
#  1457,
#  1456,
#  1507,
#  1476,
#  1475,
#  1474,
#  1451,
#  1473,
#  1453,
#  1448,
#  1463,
#  1462,
#  1466,
#  1466,
#  1465,
#  1494,
#  1493,
#  1462,
#  1455,
#  1460,
#  1490,
#  1488,
#  1488,
#  1486,
#  1486,
#  1488,
#  1483,
#  1486,
#  1485,
#  1484,
#  1483,
#  1482,
#  1481,
#  1481,
#  1480,
#  1479,
#  1488,
#  1495,
#  1476,
#  1475,
#  1473,
#  1473,
#  1472,
#  1470,
#  1469,
#  1469,
#  1468,
#  1467,
#  1465,
#  1460,
#  1463,
#  1458,
#  1457,
#  1404,
#  1403,
#  1377,
#  1303,
#  1303,
#  1301,
#  1300,
#  1299,
#  1298,
#  1297,
#  1296,
#  1296,
#  1287,
#  1293,
#  1292,
#  1315,
#  1291,
#  1289,
#  1317,
#  1288,
#  1316,
#  1312,
#  1285,
#  1307,
#  1355,
#  1305,
#  1280,
#  1352,
#  1346,
#  1344,
#  1306,
#  1348,
#  1341,
#  1299,
#  1272,
#  1295,
#  1271,
#  1336,
#  1341,
#  1340,
#  1364,
#  1338,
#  1337,
#  1263,
#  1262,
#  1261,
#  1256,
#  1250,
#  1251,
#  1235,
#  1247,
#  1250,
#  1247,
#  1248,
#  1247,
#  1244,
#  1243,
#  1245,
#  1246,
#  1243,
#  1246,
#  1241,
#  1239,
#  1239,
#  1240,
#  1237,
#  1236,
#  1235,
#  1234,
#  1233,
#  1236,
#  1235,
#  1234,
#  1233,
#  1233,
#  1232,
#  1231,
#  1327,
#  1348,
#  1377,
#  1346,
#  1375,
#  1374,
#  1344,
#  1343,
#  1371,
#  1339,
#  1292,
#  1316,
#  1315,
#  1330,
#  1335,
#  1364,
#  1363,
#  1362,
#  1361,
#  1364,
#  1364,
#  1363,
#  1362,
#  1361,
#  1360,
#  1359,
#  1358,
#  1357,
#  1356,
#  1355,
#  1364,
#  1371,
#  1371,
#  1370,
#  1368,
#  1368,
#  1367,
#  1380,
#  1380,
#  1378,
#  1378,
#  1362,
#  1374,
#  1373,
#  1359,
#  1371,
#  1357,
#  1370,
#  1389,
#  1373,
#  1372,
#  1387,
#  1388,
#  1416,
#  1415,
#  1416,
#  1413,
#  1360,
#  1345,
#  1344,
#  1340,
#  1323,
#  1322,
#  1339,
#  1338,
#  1319,
#  1318,
#  1317,
#  1335,
#  1347,
#  1350,
#  1349,
#  1348,
#  1347,
#  1346,
#  1343,
#  1344,
#  1341,
#  1342,
#  1341,
#  1340,
#  1339,
#  1340,
#  1337,
#  1336,
#  1335,
#  1336,
#  1335,
#  1335,
#  1382,
#  1381,
#  1378,
#  1377,
#  1378,
#  1377,
#  1374,
#  1375,
#  1374,
#  1372,
#  1370,
#  1369,
#  1370,
#  1367,
#  1368,
#  1367,
#  1366,
#  1365,
#  1362,
#  1363,
#  1362,
#  1361,
#  1360,
#  1416,
#  1358,
#  1357,
#  1356,
#  1355,
#  1354,
#  1353,
#  1418,
#  1419,
#  1412,
#  1407,
#  1412,
#  1405,
#  1410,
#  1412,
#  1412,
#  1410,
#  1408,
#  1399,
#  1397,
#  1396,
#  1396,
#  1399,
#  1393,
#  1393,
#  1402,
#  1401,
#  1399,
#  1399,
#  1398,
#  1395,
#  1395,
#  1393,
#  1393,
#  1387,
#  1324,
#  1380,
#  1379,
#  1383,
#  1382,
#  1377,
#  1380,
#  1379,
#  1378,
#  1375,
#  1377,
#  1371,
#  1370,
#  1378,
#  1376,
#  1375,
#  1376,
#  1375,
#  1374,
#  1374,
#  1373,
#  1372,
#  1371,
#  1370,
#  1371,
#  1370,
#  1368,
#  1368,
#  1366,
#  1364,
#  1365,
#  1362,
#  1361,
#  1361,
#  1360,
#  1857,
#  1854,
#  1853,
#  1854,
#  1851,
#  1850,
#  1849,
#  1848,
#  1853,
#  1846,
#  1351,
#  1846,
#  1843,
#  1843,
#  1841,
#  1347,
#  1343,
#  1336,
#  1339,
#  1341,
#  1338,
#  1339,
#  1338,
#  1338,
#  1831,
#  1832,
#  1830,
#  1828,
#  1829,
#  1826,
#  1825,
#  1824,
#  1823,
#  1822,
#  1822,
#  1820,
#  1819,
#  1820,
#  1819,
#  1818,
#  1321,
#  1814,
#  1813,
#  1812,
#  1811,
#  1810,
#  1809,
#  1314,
#  1310,
#  1308,
#  1297,
#  1298,
#  1294,
#  1293,
#  1293,
#  1300,
#  1299,
#  1298,
#  1299,
#  1299,
#  1297,
#  1297,
#  1295,
#  1293,
#  1292,
#  1290,
#  1289,
#  1284,
#  1288,
#  1280,
#  1279,
#  1276,
#  1283,
#  1284,
#  1283,
#  1282,
#  1279,
#  1279,
#  1279,
#  1278,
#  1280,
#  1277,
#  1277,
#  1274,
#  1274,
#  1273,
#  1272,
#  1260,
#  1259,
#  1257,
#  1199,
#  1256,
#  1255,
#  1256,
#  1252,
#  1251,
#  1250,
#  1192,
#  1191,
#  1190,
#  1134,
#  1101,
#  1100,
#  1109,
#  1116,
#  1097,
#  1096,
#  1095,
#  1093,
#  1093,
#  1092,
#  1091,
#  1122,
#  1107,
#  1124,
#  1120,
#  1122,
#  1121,
#  1125,
#  1130,
#  1120,
#  1117,
#  1134,
#  1133,
#  1163,
#  1157,
#  1114,
#  1113,
#  1112,
#  1111,
#  1108,
#  1103,
#  1102,
#  1101,
#  1106,
#  1105,
#  1113,
#  1150,
#  1151,
#  1208,
#  1207,
#  1206,
#  1204,
#  1146,
#  1202,
#  1207,
#  1201,
#  1142,
#  1198,
#  1140,
#  1139,
#  1195,
#  1194,
#  1136,
#  1135,
#  1132,
#  1133,
#  1132,
#  1188,
#  1192,
#  1192,
#  1196,
#  1195,
#  1194,
#  1194,
#  1192,
#  1192,
#  1190,
#  1190,
#  1189,
#  1188,
#  1189,
#  1188,
#  1187,
#  1187,
#  1680,
#  1185,
#  1678,
#  1183,
#  1182,
#  1675,
#  1674,
#  1179,
#  1672,
#  1671,
#  1670,
#  1669,
#  1668,
#  1667,
#  1666,
#  1665,
#  1664,
#  1663,
#  1662,
#  1661,
#  1660,
#  1659,
#  1658,
#  1161,
#  1158,
#  1155,
#  1154,
#  1157,
#  1158,
#  1157,
#  1156,
#  1649,
#  1648,
#  1649,
#  1648,
#  1647,
#  1646,
#  1648,
#  1644,
#  1646,
#  1646,
#  1644,
#  1643,
#  1643,
#  1638,
#  1637,
#  1640,
#  1639,
#  1638,
#  1637,
#  1636,
#  1635,
#  1634,
#  1633,
#  1632,
#  1630,
#  1630,
#  1629,
#  1628,
#  1627,
#  1626,
#  1625,
#  1624,
#  1623,
#  1622,
#  1621,
#  1619,
#  1618,
#  1617,
#  1616,
#  1614,
#  1611,
#  1613,
#  1611,
#  1608,
#  1607,
#  1606,
#  1605,
#  1604,
#  1603,
#  1602,
#  1601,
#  1600,
#  1599,
#  1598,
#  1597,
#  1596,
#  1595,
#  1594,
#  1595,
#  1594,
#  1594,
#  1593,
#  1591,
#  1590,
#  1589,
#  1586,
#  1585,
#  1584,
#  1583,
#  1582,
#  1581,
#  1580,
#  1577,
#  1576,
#  1577,
#  1576,
#  1575,
#  1574,
#  1573,
#  1572,
#  1571,
#  1570,
#  1569,
#  1568,
#  1567,
#  1566,
#  1565,
#  1562,
#  1561,
#  1560,
#  1559,
#  1558,
#  1557,
#  1556,
#  1555,
#  1555,
#  1555,
#  1554,
#  1553,
#  1552,
#  1555,
#  1553,
#  1553,
#  1552,
#  1551,
#  1549,
#  1549,
#  1548,
#  1547,
#  1546,
#  1545,
#  1544,
#  1539,
#  1536,
#  1535,
#  1534,
#  1535,
#  1532,
#  1533,
#  1532,
#  1531,
#  1530,
#  1527,
#  1526,
#  1525,
#  1030,
#  1029,
#  1522,
#  1522,
#  1522,
#  1519,
#  1518,
#  1518,
#  1518,
#  1515,
#  1020,
#  1017,
#  1018,
#  1511,
#  1510,
#  1509,
#  1014,
#  1013,
#  1506,
#  1010,
#  1009,
#  1005,
#  1007,
#  1005,
#  1005,
#  1005,
#  1004,
#  1003,
#  1001,
#  1001,
#  996,
#  997,
#  994,
#  995,
#  994,
#  992,
#  993,
#  990,
#  988,
#  988,
#  987,
#  985,
#  983,
#  972,
#  980,
#  981,
#  978,
#  978,
#  978,
#  977,
#  974,
#  975,
#  975,
#  974,
#  974,
#  975,
#  973,
#  972,
#  971,
#  970,
#  969,
#  968,
#  968,
#  967,
#  966,
#  963,
#  962,
#  962,
#  961,
#  959,
#  948,
#  953,
#  886,
#  943,
#  941,
#  941,
#  945,
#  944,
#  880,
#  879,
#  878,
#  877,
#  808,
#  835,
#  825,
#  827,
#  839,
#  822,
#  830,
#  821,
#  819,
#  818,
#  817,
#  814,
#  815,
#  812,
#  809,
#  808,
#  773,
#  790,
#  790,
#  787,
#  788,
#  800,
#  799,
#  798,
#  784,
#  782,
#  763,
#  762,
#  760,
#  759,
#  759,
#  757,
#  757,
#  775,
#  787,
#  787,
#  787,
#  788,
#  787,
#  786,
#  783,
#  781,
#  781,
#  780,
#  779,
#  778,
#  799,
#  796,
#  795,
#  827,
#  826,
#  825,
#  824,
#  823,
#  880,
#  878,
#  883,
#  885,
#  886,
#  885,
#  886,
#  887,
#  885,
#  884,
#  884,
#  882,
#  881,
#  879,
#  878,
#  878,
#  877,
#  876,
#  874,
#  874,
#  873,
#  872,
#  871,
#  868,
#  867,
#  866,
#  864,
#  862,
#  861,
#  862,
#  860,
#  859,
#  856,
#  856,
#  856,
#  855,
#  853,
#  853,
#  851,
#  851,
#  850,
#  849,
#  848,
#  847,
#  847,
#  845,
#  844,
#  843,
#  844,
#  841,
#  840,
#  840,
#  839,
#  838,
#  837,
#  837,
#  836,
#  836,
#  835,
#  834,
#  833,
#  830,
#  829,
#  828,
#  828,
#  824,
#  825,
#  824,
#  824,
#  824,
#  823,
#  820,
#  819,
#  818,
#  817,
#  816,
#  814,
#  815,
#  813,
#  815,
#  814,
#  1307,
#  1306,
#  1305,
#  1306,
#  1305,
#  1304,
#  1301,
#  1300,
#  1299,
#  1298,
#  1297,
#  1296,
#  1295,
#  1294,
#  1293,
#  1292,
#  1291,
#  1290,
#  1289,
#  1288,
#  1287,
#  1286,
#  1285,
#  1284,
#  1283,
#  1282,
#  1281,
#  1280,
#  1279,
#  1280,
#  1279,
#  1278,
#  1276,
#  1276,
#  1275,
#  1274,
#  1275,
#  1275,
#  1275,
#  1272,
#  1273,
#  1270,
#  1270,
#  1270,
#  1269,
#  1268,
#  1267,
#  1266,
#  1265,
#  1264,
#  1263,
#  1262,
#  1261,
#  1260,
#  1259,
#  1262,
#  1257,
#  1259,
#  1255,
#  1254,
#  1256,
#  1252,
#  1251,
#  1254,
#  1254,
#  1253,
#  1252,
#  1251,
#  1250,
#  1250,
#  1249,
#  1248,
#  1247,
#  1246,
#  1245,
#  1244,
#  1242,
#  1241,
#  1240,
#  1240,
#  1239,
#  1237,
#  1236,
#  1236,
#  1235,
#  1233,
#  1233,
#  1232,
#  1231,
#  1231,
#  1230,
#  1229,
#  1228,
#  1227,
#  1226,
#  1225,
#  1227,
#  1232,
#  1230,
#  1230,
#  1229,
#  1228,
#  1226,
#  1225,
#  ...]

# %%
#page4

#mean

def get_mean(ls):
    v=[]
    for r in ls:
        if r==0:
            continue
        else:
            v.append(r)
    return sum(v)/len(v)


#median with unique entries


def get_median(ls):
    q=[]
    for r in ls:
        if r not in q:
            q.append(r)
    # sort the list
            q.sort()
#     print(q)
        
    # find the median
    if len(q) % 2 != 0:
        m = int((len(q)+1)/2 - 1)
        return q[m]
    else:
        m1 = int(len(q)/2 - 1)
        m2 = int(len(q)/2)
        return (q[m1]+q[m2])/2

#probability of liquidation/no of cases where liquidation occurs
def get_prob(ls):
    q=[]
    w=len(ls)
    for r in ls:
        if r!=0:
            q.append(r)
    return (len(q)/len(ls))*100

    
print("mean:"+str(get_mean(x)))
print("median:"+str(get_median(x)))
print("probability of liquidation:"+str(get_prob(x)))
# Out:
# mean:2231.7787470261696
# median:2407.5
# probability of liquidation:57.5733363771259

# %%
#page1 XRP

import pandas as pd
# data_df=  pd.read_csv(r'C:\Users\advai\Downloads\Data-30mins.csv')
data_df=  pd.read_csv(r'C:\Users\advai\Downloads\Data-1hr.csv')
# data_df=  pd.read_csv(r'C:\Users\advai\Downloads\raw_data_83_days.csv')
# k= 200*(data_df.at[0,'BTC/USD']/data_df.at[0,'ADA/USD'])

def format_float(value):
    return f'{value:,.5f}'
pd.options.display.float_format = format_float

rows=data_df.shape[0]
a = []
for i in range (0,rows):
    b = []
#     print(i)
    for j in range(i,rows):
        if j==i:
            k=200*(data_df.at[i,'XRP/USD']/data_df.at[i,'ADA/USD'])
        
        
        else:
#               data_df.at[i,'constant']=data_df.at[0,'constant']*(data_df.at[i,'ADA/USD']/data_df.at[i,'BTC/USD'])
            z=k*(data_df.at[j,'ADA/USD']/data_df.at[j,'XRP/USD'])
            b.append(z)
    a.append(b)

# %%
#page2
MCR= 145
x=[]
for m in range (0,len(a)):
    y=a[m]
    for n in range (0,len(y)):    
        f = 0 
        if y[n] < MCR:
            f = 1
#             print(n)
            x.append(n)
            break
    if f == 0:
        x.append(0)
#         print(n)

# %%
#page3
a
# x

# %%
#page4

#mean

def get_mean(ls):
    v=[]
    for r in ls:
        if r==0:
            continue
        else:
            v.append(r)
    return sum(v)/len(v)


#median with unique entries


def get_median(ls):
    q=[]
    for r in ls:
        if r not in q:
            q.append(r)
    # sort the list
            q.sort()
#     print(q)
        
    # find the median
    if len(q) % 2 != 0:
        m = int((len(q)+1)/2 - 1)
        return q[m]
    else:
        m1 = int(len(q)/2 - 1)
        m2 = int(len(q)/2)
        return (q[m1]+q[m2])/2

#probability of liquidation/no of cases where liquidation occurs
def get_prob(ls):
    q=[]
    w=len(ls)
    for r in ls:
        if r!=0:
            q.append(r)
    return (len(q)/len(ls))*100

    
print("mean:"+str(get_mean(x)))
print("median:"+str(get_median(x)))
print("probability of liquidation:"+str(get_prob(x)))
# Out:
# mean:1466.15462700661
# median:1515
# probability of liquidation:48.35064490354982

# %%
#page1 SOL

import pandas as pd
# data_df=  pd.read_csv(r'C:\Users\advai\Downloads\Data-30mins.csv')
data_df=  pd.read_csv(r'C:\Users\advai\Downloads\Data-1hr.csv')
# data_df=  pd.read_csv(r'C:\Users\advai\Downloads\raw_data_83_days.csv')
# k= 200*(data_df.at[0,'BTC/USD']/data_df.at[0,'ADA/USD'])

def format_float(value):
    return f'{value:,.5f}'
pd.options.display.float_format = format_float

rows=data_df.shape[0]
a = []
for i in range (0,rows):
    b = []
#     print(i)
    for j in range(i,rows):
        if j==i:
            k=200*(data_df.at[i,'SOL/USD']/data_df.at[i,'ADA/USD'])
        
        
        else:
#               data_df.at[i,'constant']=data_df.at[0,'constant']*(data_df.at[i,'ADA/USD']/data_df.at[i,'BTC/USD'])
            z=k*(data_df.at[j,'ADA/USD']/data_df.at[j,'SOL/USD'])
            b.append(z)
    a.append(b)

# %%
#page2
MCR= 140
x=[]
for m in range (0,len(a)):
    y=a[m]
    for n in range (0,len(y)):    
        f = 0 
        if y[n] < MCR:
            f = 1
#             print(n)
            x.append(n)
            break
    if f == 0:
        x.append(0)
#         print(n)

# %%
#page3
# a
x

# %%
#page4

#mean

def get_mean(ls):
    v=[]
    for r in ls:
        if r==0:
            continue
        else:
            v.append(r)
    return sum(v)/len(v)


#median with unique entries


def get_median(ls):
    q=[]
    for r in ls:
        if r not in q:
            q.append(r)
    # sort the list
            q.sort()
#     print(q)
        
    # find the median
    if len(q) % 2 != 0:
        m = int((len(q)+1)/2 - 1)
        return q[m]
    else:
        m1 = int(len(q)/2 - 1)
        m2 = int(len(q)/2)
        return (q[m1]+q[m2])/2

#probability of liquidation/no of cases where liquidation occurs
def get_prob(ls):
    q=[]
    w=len(ls)
    for r in ls:
        if r!=0:
            q.append(r)
    return (len(q)/len(ls))*100

    
print("mean:"+str(get_mean(x)))
print("median:"+str(get_median(x)))
print("probability of liquidation:"+str(get_prob(x)))
# Out:
# mean:650.7716306156406
# median:699.5
# probability of liquidation:27.43978997831298

# %%
#page1 EUR

import pandas as pd
# data_df=  pd.read_csv(r'C:\Users\advai\Downloads\Data-30mins.csv')
data_df=  pd.read_csv(r'C:\Users\advai\Downloads\Data-1hr.csv')
# data_df=  pd.read_csv(r'C:\Users\advai\Downloads\raw_data_83_days.csv')
# k= 200*(data_df.at[0,'BTC/USD']/data_df.at[0,'ADA/USD'])

def format_float(value):
    return f'{value:,.5f}'
pd.options.display.float_format = format_float

rows=data_df.shape[0]
a = []
for i in range (0,rows):
    b = []
#     print(i)
    for j in range(i,rows):
        if j==i:
            k=200*(data_df.at[i,'EUR/USD']/data_df.at[i,'ADA/USD'])
        
        
        else:
#               data_df.at[i,'constant']=data_df.at[0,'constant']*(data_df.at[i,'ADA/USD']/data_df.at[i,'BTC/USD'])
            z=k*(data_df.at[j,'ADA/USD']/data_df.at[j,'EUR/USD'])
            b.append(z)
    a.append(b)

# %%
#page2
x=[]
MCR=140
for m in range (0,len(a)):
    y=a[m]
    for n in range (0,len(y)):    
        f = 0 
        if y[n] < MCR:
            f = 1
#             print(n)
            x.append(n)
            break
    if f == 0:
        x.append(0)
#         print(n)

# %%
#page3
# a
x

# %%
#page4

#mean

def get_mean(ls):
    v=[]
    for r in ls:
        if r==0:
            continue
        else:
            v.append(r)
    return sum(v)/len(v)


#median with unique entries


def get_median(ls):
    q=[]
    for r in ls:
        if r not in q:
            q.append(r)
    # sort the list
            q.sort()
#     print(q)
        
    # find the median
    if len(q) % 2 != 0:
        m = int((len(q)+1)/2 - 1)
        return q[m]
    else:
        m1 = int(len(q)/2 - 1)
        m2 = int(len(q)/2)
        return (q[m1]+q[m2])/2

#probability of liquidation/no of cases where liquidation occurs
def get_prob(ls):
    q=[]
    w=len(ls)
    for r in ls:
        if r!=0:
            q.append(r)
    return (len(q)/len(ls))*100

    
print("mean:"+str(get_mean(x)))
print("median:"+str(get_median(x)))
print("probability of liquidation:"+str(get_prob(x)))
